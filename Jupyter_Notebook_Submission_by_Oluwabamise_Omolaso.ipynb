# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Oluwabamise Omolaso**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because I love making data driven decisions.*
#
# *I love how data tranforms businessess and would love to build machine learning models that will make an impact on the world*

# %% [markdown]
# ### The code in cell 5 is a python function for addition of any two numbers

# %%
def add(a,b):
  a = 5
  b = 6
  return (a+b)

add(4,7)
# Out:
# 11

# %% [markdown]
# Horizontal Rule
#
# ---
#
# Bulleted List
#
#
#
# *   List item 1
# *   List item 2
#
#
# Numbered List
#
#
# 1.   List item A
# 2.   List item B
#
# Hyperlink
#
# [Click to Google Search](https://https://www.google.com/search?q=google&rlz=1C1CHBF_enNG1004NG1004&oq=google&aqs=chrome..69i57j46i131i199i433i465i512j69i60l3j69i65l2j5.2568j0j7&sourceid=chrome&ie=UTF-8)
#
# ![impact-of-artificial-intelligence-in-healthcare-trends_86409.jfif](data:image/jpeg;base64,...)
